# %% [markdown]
# <a href="https://colab.research.google.com/github/drewjd27/CNN-potato-disease-classification/blob/main/converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=6194f6f61367d715c18c875f976e70a8da5f19126c56a46877c508e003cab68b
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# ...

# %%
model = tf.keras.models.load_model("model_e.keras")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('model_e.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpuz8ykemt'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   135511174334592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174338288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174709840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174713184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174717936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174720224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174724272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174723392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135511174869792: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
