# %% [markdown]
# <a href="https://colab.research.google.com/github/drewjd27/CNN-potato-disease-classification/blob/main/converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
# !pip install utils
# Out:
# Collecting utils
#   Downloading utils-1.0.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utils
#   Building wheel for utils (setup.py) ... done
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=2ff7f07943312c373cc6c894e3b87cee4eaf7d551fe290dd642e2b9c3aea7229
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# Installing collected packages: utils
# Successfully installed utils-1.0.2

# %%
model = tf.keras.models.load_model("model_e.keras")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 18 variables whereas the saved optimizer has 34 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Saved artifact at '/tmp/tmperu3bxjw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(32, 256, 256, 3), dtype=tf.float32, name='input_layer_9')
# Output Type:
#   TensorSpec(shape=(32, 3), dtype=tf.float32, name=None)
# Captures:
#   136729778624240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729778627936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776083840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776086480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776091232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729775999456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776001744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776005792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776008080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776012128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776011248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776560032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776563200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136732167635888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136729776702560: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
with open('model_e.tflite', 'wb') as f:
  f.write(tflite_model)
